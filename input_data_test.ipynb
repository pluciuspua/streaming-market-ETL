# %%
from dotenv import load_dotenv
import json, time, requests, os
import pprint
load_dotenv()
API_KEY = os.getenv("ALPHAVANTAGE_API_KEY")
print(API_KEY)
# Out:
# SPLBTVZDT2DLW2L5

# %%
SYMBOL = "AAPL"

def fetch_stock_price(symbol):
    url = f"https://www.alphavantage.co/query"
    params = {
        "function": "NEWS_SENTIMENT",
        "tickers": symbol,
        "apikey": API_KEY,
        "sort": "RELEVANCE",
        "time_from":"20250914T0000"
    }
    r = requests.get(url, params=params).json()
    pprint.pprint(r)

fetch_stock_price(SYMBOL)
# Out:
# {'feed': [{'authors': ['Keithen Drury'],
#            'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F832297%2Ftwo-people-in-suits-looking-at-data.jpg&op=resize&w=700',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.281474,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': 'Alphabet and Apple are two of the most recognizable '
#                       'names in big tech.',
#            'ticker_sentiment': [{'relevance_score': '0.061949',
#                                  'ticker': 'BBY',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.093016'},
#                                 {'relevance_score': '0.359014',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.137654'},
#                                 {'relevance_score': '0.648995',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.392776'}],
#            'time_published': '20250913T124300',
#            'title': 'Best Stock to Buy Now: Alphabet or Apple?',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Retail & Wholesale'},
#                       {'relevance_score': '0.214378',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.938793', 'topic': 'Earnings'},
#                       {'relevance_score': '0.5', 'topic': 'Technology'}],
#            'url': 'https://www.fool.com/investing/2025/09/13/best-stock-to-buy-now-alphabet-or-apple/'},
#           {'authors': ['Rick Orford'],
#            'banner_image': 'https://g.foolcdn.com/editorial/images/833345/cash-form-s-1-ipo-1200x800-5b2df79.jpg',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.181731,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': "Apple's $20 billion search deal lifeline could be the "
#                       "hidden catalyst Wall Street is overlooking -- here's "
#                       'why it matters for investors right now.',
#            'ticker_sentiment': [{'relevance_score': '0.17715',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.316704'},
#                                 {'relevance_score': '0.629492',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.003766'}],
#            'time_published': '20250913T143000',
#            'title': 'Massive News for Apple Stock Investors',
#            'topics': [{'relevance_score': '0.360215', 'topic': 'Earnings'},
#                       {'relevance_score': '1.0', 'topic': 'Technology'},
#                       {'relevance_score': '0.684621',
#                        'topic': 'Financial Markets'}],
#            'url': 'https://www.fool.com/investing/2025/09/13/massive-news-for-apple-stock-investors/'},
#           {'authors': ['Neil Patel'],
#            'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F830158%2Ftrader-pondering-at-screens.jpg&op=resize&w=700',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Bullish',
#            'overall_sentiment_score': 0.356498,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': 'The AI revolution has made Nvidia the most valuable '
#                       'company on the planet.',
#            'ticker_sentiment': [{'relevance_score': '0.604596',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.502495'},
#                                 {'relevance_score': '0.604596',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.509214'}],
#            'time_published': '20250913T074000',
#            'title': 'Is Apple Stock as Good as Nvidia?',
#            'topics': [{'relevance_score': '0.929393',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.538269', 'topic': 'Earnings'},
#                       {'relevance_score': '0.5', 'topic': 'Technology'}],
#            'url': 'https://www.fool.com/investing/2025/09/13/is-apple-stock-as-good-as-nvidia/'},
#           {'authors': ['Prosper Junior Bakiny'],
#            'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F832838%2Fwoman-looking-at-smarphone.jpg&op=resize&w=700',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Bullish',
#            'overall_sentiment_score': 0.362643,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': 'Their prospects look intact despite some recent '
#                       'roadblocks.',
#            'ticker_sentiment': [{'relevance_score': '0.38716',
#                                  'ticker': 'LLY',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.316712'},
#                                 {'relevance_score': '0.484697',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Bullish',
#                                  'ticker_sentiment_score': '0.46651'}],
#            'time_published': '20250913T114500',
#            'title': '2 Beaten-Down Stocks to Buy and Hold Forever',
#            'topics': [{'relevance_score': '0.5', 'topic': 'Life Sciences'},
#                       {'relevance_score': '0.266143',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.161647', 'topic': 'Earnings'},
#                       {'relevance_score': '0.5', 'topic': 'Technology'}],
#            'url': 'https://www.fool.com/investing/2025/09/13/2-beaten-down-stocks-to-buy-and-hold-forever/'},
#           {'authors': ['Anthony Di Pizio'],
#            'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F832889%2Fwarren-buffett-looking-at-the-camera.jpg&op=resize&w=700',
#            'category_within_source': 'n/a',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.248776,
#            'source': 'Motley Fool',
#            'source_domain': 'www.fool.com',
#            'summary': "Warren Buffett's investments in stocks like Apple and "
#                       'Coca-Cola have propelled Berkshire Hathaway to '
#                       'market-beating returns for six decades.',
#            'ticker_sentiment': [{'relevance_score': '0.151222',
#                                  'ticker': 'KO',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.063715'},
#                                 {'relevance_score': '0.343619',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.190594'},
#                                 {'relevance_score': '0.101154',
#                                  'ticker': 'BRK-A',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.076653'}],
#            'time_published': '20250913T085100',
#            'title': 'Meet the $1 Trillion Stock Warren Buffett Has Plowed '
#                     '$77.8 Billion Into Since 2018',
#            'topics': [{'relevance_score': '0.692272',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.333333', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.fool.com/investing/2025/09/13/1-trillion-stock-warren-buffett-778-billion-2018/'},
#           {'authors': ['Rishabh Mishra'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/09/13/Close-Up-Of-Wall-Street-Sign-With-Iconic.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'General',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.157232,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': 'Retail investors buzzed about five stocks this week, '
#                       "from Sept. 8 to 12, on platforms like X and Reddit's "
#                       'r/WallStreetBets, amid market volatility and enthusiasm '
#                       'for AI. The stocks, Oracle Corp. ORCL, Opendoor '
#                       'Technologies Inc. OPEN, Nebius Group NV NBIS, '
#                       'UnitedHealth Group Inc. UNH, and Apple ...',
#            'ticker_sentiment': [{'relevance_score': '0.123209',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.183895',
#                                  'ticker': 'ORCL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.054945'},
#                                 {'relevance_score': '0.183895',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.180127'},
#                                 {'relevance_score': '0.243498',
#                                  'ticker': 'UNH',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.009367'},
#                                 {'relevance_score': '0.243498',
#                                  'ticker': 'OPEN',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.190931'}],
#            'time_published': '20250913T123007',
#            'title': "5 Stocks Investors Couldn't Stop Talking About This Week- "
#                     "Here's How They Fared: ORCL, OPEN, NBIS, UNH, AAPL - "
#                     'Microsoft  ( NASDAQ:MSFT ) , Apple  ( NASDAQ:AAPL ) ',
#            'topics': [{'relevance_score': '1.0', 'topic': 'Financial Markets'},
#                       {'relevance_score': '0.158519', 'topic': 'Earnings'},
#                       {'relevance_score': '0.333333',
#                        'topic': 'Real Estate & Construction'},
#                       {'relevance_score': '0.333333', 'topic': 'Technology'},
#                       {'relevance_score': '0.333333', 'topic': 'Finance'}],
#            'url': 'https://www.benzinga.com/markets/equities/25/09/47656226/5-stocks-investors-couldnt-stop-talking-about-this-week-heres-how-they-fared-orcl-open-nbis-unh-'},
#           {'authors': ['Benzinga Senior Editor'],
#            'banner_image': 'https://cdn.benzinga.com/files/images/story/2025/09/13/Bulls-and-Bears-1.jpeg?width=1200&height=800&fit=crop',
#            'category_within_source': 'Markets',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.16469,
#            'source': 'Benzinga',
#            'source_domain': 'www.benzinga.com',
#            'summary': "Benzinga examined the prospects for many investors' "
#                       "favorite stocks over the last week - here's a look at "
#                       'some of our top stories. Wall Street hit fresh records '
#                       'this week, partly due to rising optimism that the Fed '
#                       'will cut interest rates soon, even as inflation sits at '
#                       '~2.9% and jobless claims ...',
#            'ticker_sentiment': [{'relevance_score': '0.105372',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.041279'},
#                                 {'relevance_score': '0.105372',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.041279'},
#                                 {'relevance_score': '0.105372',
#                                  'ticker': 'TSLA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.041279'},
#                                 {'relevance_score': '0.157483',
#                                  'ticker': 'NIO',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.027545'},
#                                 {'relevance_score': '0.208914',
#                                  'ticker': 'MU',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.095982'},
#                                 {'relevance_score': '0.157483',
#                                  'ticker': 'SNPS',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.074567'},
#                                 {'relevance_score': '0.157483',
#                                  'ticker': 'LE',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '-0.098528'},
#                                 {'relevance_score': '0.259451',
#                                  'ticker': 'ORCL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.082302'},
#                                 {'relevance_score': '0.157483',
#                                  'ticker': 'UNH',
#                                  'ticker_sentiment_label': 'Somewhat-Bullish',
#                                  'ticker_sentiment_score': '0.312187'}],
#            'time_published': '20250913T120116',
#            'title': "Bulls And Bears: Oracle, Micron, Land's End - And Ellison "
#                     'Briefly Bests Musk Bulls And Bears: Oracle, Micron, '
#                     "Land's End - And Ellison Briefly Bests Musk - Apple  ( "
#                     'NASDAQ:AAPL ) , Adobe  ( NASDAQ:ADBE ) ',
#            'topics': [{'relevance_score': '0.25', 'topic': 'Technology'},
#                       {'relevance_score': '0.25', 'topic': 'Finance'},
#                       {'relevance_score': '0.310843',
#                        'topic': 'Economy - Monetary'},
#                       {'relevance_score': '0.25',
#                        'topic': 'Retail & Wholesale'},
#                       {'relevance_score': '0.54554',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.25', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.999941', 'topic': 'Earnings'}],
#            'url': 'https://www.benzinga.com/markets/market-summary/25/09/47656195/benzinga-bulls-and-bears-oracle-micron-lands-end-and-ellison-briefly-bests-musk'},
#           {'authors': ['Jeff Remsburg'],
#            'banner_image': 'https://investorplace.com/wp-content/uploads/2025/09/image-50.png',
#            'category_within_source': 'RSS',
#            'overall_sentiment_label': 'Somewhat-Bullish',
#            'overall_sentiment_score': 0.217614,
#            'source': 'Business Insider',
#            'source_domain': 'markets.businessinsider.com',
#            'summary': 'Why Eric Fry remains bullish on Oracle even after its '
#                       "price surge… Luke Lango's notes from Day 3 of the "
#                       "All-In Summit… how to invest in XPU's today On "
#                       'Wednesday, Oracle Corp. ( ORCL ) surged 38% after the '
#                       'company announced blowout guidance. It was the tech '
#                       "company's best single-day performance ...",
#            'ticker_sentiment': [{'relevance_score': '0.026562',
#                                  'ticker': 'MSFT',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.071026'},
#                                 {'relevance_score': '0.026562',
#                                  'ticker': 'GOOG',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.079568',
#                                  'ticker': 'NVDA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.026582'},
#                                 {'relevance_score': '0.026562',
#                                  'ticker': 'AAPL',
#                                  'ticker_sentiment_label': 'Somewhat-Bearish',
#                                  'ticker_sentiment_score': '-0.198079'},
#                                 {'relevance_score': '0.132222',
#                                  'ticker': 'AVGO',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.120802'},
#                                 {'relevance_score': '0.026562',
#                                  'ticker': 'TSLA',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.0'},
#                                 {'relevance_score': '0.053094',
#                                  'ticker': 'SNPS',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.060721'},
#                                 {'relevance_score': '0.310516',
#                                  'ticker': 'ORCL',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.096517'},
#                                 {'relevance_score': '0.026562',
#                                  'ticker': 'OPTGF',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.079406'},
#                                 {'relevance_score': '0.053094',
#                                  'ticker': 'TSM',
#                                  'ticker_sentiment_label': 'Neutral',
#                                  'ticker_sentiment_score': '0.060721'}],
#            'time_published': '20250913T002006',
#            'title': "Don't Take Profits on This Big Winner Yet",
#            'topics': [{'relevance_score': '0.54554',
#                        'topic': 'Financial Markets'},
#                       {'relevance_score': '0.5', 'topic': 'Manufacturing'},
#                       {'relevance_score': '0.994953', 'topic': 'Earnings'},
#                       {'relevance_score': '0.5', 'topic': 'Technology'},
#                       {'relevance_score': '0.158519',
#                        'topic': 'Economy - Macro'}],
#            'url': 'https://markets.businessinsider.com/news/stocks/dont-take-profits-on-this-big-winner-yet-1035141911'}],
#  'items': '8',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating '
#                                'higher relevance.',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: '
#                                'Somewhat-Bearish; -0.15 < x < 0.15: Neutral; '
#                                '0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: '
#                                'Bullish'}
